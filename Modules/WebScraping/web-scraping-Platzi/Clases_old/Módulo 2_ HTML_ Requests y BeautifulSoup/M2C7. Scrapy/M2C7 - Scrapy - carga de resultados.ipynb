# %%
import pandas as pd

# %%
df = pd.read_json('resultados.json')
df
# Out:
#                                                    url  \
# 0    https://www.pagina12.com.ar/227209-macri-se-de...
# 1    https://www.pagina12.com.ar/autores/852-javier...
# 2    https://www.pagina12.com.ar/227126-las-pymes-q...
# 3    https://www.pagina12.com.ar/autores/204465-flo...
# 4    https://www.pagina12.com.ar/227141-se-profundi...
# ..                                                 ...
# 132  https://www.pagina12.com.ar/autores/1050-raul-...
# 133  https://www.pagina12.com.ar/227111-el-dolar-ya...
# 134  https://www.pagina12.com.ar/227101-entrenan-ra...
# 135  https://www.pagina12.com.ar/227233-el-dolar-ar...
# 136  https://www.pagina12.com.ar/227242-dolar-macri...
#
#                                                 titulo  \
# 0              Macri se despide con los peores números
# 1                                                 None
# 2              Las pymes quieren que Sandleris se vaya
# 3                                                 None
# ...
