# %%
import requests
import numpy as np
import pandas as pd

# %% [markdown]
# https://developer.spotify.com/documentation/web-api/reference/artists/

# %%
url_base = 'https://api.spotify.com'

# %% [markdown]
# Intentemos acceder a la información de algún artista. Iron Maiden.

# %%
# Obtenemos el id del artista de la página de Spotify
id_im = '6mdiAmATAx73kdxrNrnlao'

# %%
r = requests.get(url_base+f'/v1/artists/{id_im}')
r.status_code
# Out:
# 401

# %% [markdown]
# Obtuvimos un error 401: Unauthorized.

# %%
r.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %% [markdown]
# Esto es porque Spotify nos pide un token para poder utilizar las APIs.

# %% [markdown]
# ## Autenticación / autorización
#
# Primero debemos crear un Client ID que es el que usaremos para acceder a la información a través de las APIs de Spotify. https://developer.spotify.com/documentation/general/guides/app-settings/#register-your-app<br>
# <br>
# Para codificar en base 64 https://www.base64encode.org/

# %%
header={'Authorization': 'Basic NDRiN2IzNmVjMTQ1NDY3ZjlhOWVlYWY3ZTQxN2NmOGI6N2I0YWE3YTBlZjQ4NDQwNDhhYjFkMjI0MzBhMWViMWY='}

# %%
params = {'grant_type':'client_credentials'}

# %%
r = requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{"access_token":"BQAjs24taiIyx3zrzRaDFKmP365q8b6Mnud9f-eJpfode3T4FpErW5nfjgicKy0vCZSDjraPR4JuFflgO7k","token_type":"Bearer","expires_in":3600,"scope":""}'

# %%
r.json()
# Out:
# {'access_token': 'BQAjs24taiIyx3zrzRaDFKmP365q8b6Mnud9f-eJpfode3T4FpErW5nfjgicKy0vCZSDjraPR4JuFflgO7k',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
token = r.json()['access_token']

# %% [markdown]
# Ahora que tenemos el TOKEN para la autenticación, podemos hacer uso de las apis con el siguiente encabezado

# %%
header = {'Authorization': f'Bearer {token}'}

# %% [markdown]
# Como el token recibido tiene una validez limitada, tal vez sea necesario realizar el proceso de autenticación varias veces en caso de que expire el token.

# %%
import base64
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes(client_id+':'+client_secret, 'utf-8'))
    params = {'grant_type':'client_credentials'}
    header={'Authorization': 'Basic ' + str(encoded, 'utf-8')}
    r = requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None
    print('Token válido por {} segundos.'.format(r.json()['expires_in']))
    return r.json()['access_token']

# %%
client_id = '44b7b36ec145467f9a9eeaf7e417cf8b'
client_secret = '7b4aa7a0ef4844048ab1d22430a1eb1f'

# %%
token = get_token(client_id, client_secret)
# Out:
# Token válido por 3600 segundos.

# %% [markdown]
# ### Obtener información de un artista

# %%
iron_maiden = requests.get(url_base+f'/v1/artists/{id_im}', headers=header)

# %%
iron_maiden.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#  'followers': {'href': None, 'total': 4687086},
#  'genres': ['album rock', 'hard rock', 'metal', 'nwobhm', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#  'id': '6mdiAmATAx73kdxrNrnlao',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/4da0201eb9473be7d6dd138b81678e79dfd7eb02',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/7f99805fcfe3bf12e6c29977200c7e58c234c010',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/32b9989c0c47736535d76564ed6ae11ebb57948c',
#    'width': 160}],
#  'name': 'Iron Maiden',
#  'popularity': 76,
#  'type': 'artist',
#  'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}

# %% [markdown]
# Los álbumes que tiene publicados

# %%
ep = f'/v1/artists/{id_im}/albums'

# %%
albumes_im = requests.get(url_base+ep, headers=header)

# %%
albumes_im.status_code
# Out:
# 200

# %%
albumes_im.json()
# Out:
# {'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao/albums?offset=0&limit=20&include_groups=album,single,compilation,appears_on',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
# ...

# %%
albumes_im.json().keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
albumes_im.json()['items']
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IS',
#    'IT',
#    'JP',
#    'KW',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
# ...

# %%
albumes_im.json()['items'][11]['name']
# Out:
# 'The Final Frontier (2015 Remaster)'

# %%
albumes_im.json()['items'][11]['id']
# Out:
# '5YAfxU5OZKqAvE1GZPRQYY'

# %% [markdown]
# ### API para búsqueda

# %%
ep_busqueda = 'https://api.spotify.com/v1/search'

# %%
header = {'Authorization': f'Bearer {token}'}

# %%
search_params = {'q': 'Iron Maiden'.replace(' ', '+'), 'type': 'artist', 'market': 'AR'}

# %%
busqueda = requests.get(ep_busqueda, headers=header, params=search_params)
busqueda.status_code
# Out:
# 200

# %%
pd.DataFrame(busqueda.json()['artists']['items']).sort_values(by='popularity', ascending=False).loc[0,['name', 'id']]
# Out:
# name               Iron Maiden
# id      6mdiAmATAx73kdxrNrnlao
# Name: 0, dtype: object

# %% [markdown]
# ### Obtener la información de un álbum
#
# Para obtener la información de un álbum debemos hacer un GET al endpoint /v1/albums/{id}

# %%
album_ep = '/v1/albums/{}'

# %%
album_ep.format(albumes_im.json()['items'][11]['id'])
# Out:
# '/v1/albums/5YAfxU5OZKqAvE1GZPRQYY'

# %%
url_base+album_ep.format(albumes_im.json()['items'][11]['id'])
# Out:
# 'https://api.spotify.com/v1/albums/5YAfxU5OZKqAvE1GZPRQYY'

# %%
final_frontier = requests.get(url_base+album_ep.format(albumes_im.json()['items'][11]['id']), headers=header)
final_frontier.status_code
# Out:
# 200

# %%
final_frontier.json().keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'total_tracks', 'tracks', 'type', 'uri'])

# %%
final_frontier.json()['tracks']['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
# ...

# %%
for track in final_frontier.json()['tracks']['items']:
    print(track['name'])
# Out:
# Satellite 15.....The Final Frontier - 2015 Remaster
# El Dorado - 2015 Remaster
# Mother of Mercy - 2015 Remaster
# Coming Home - 2015 Remaster
# The Alchemist - 2015 Remaster
# Isle of Avalon - 2015 Remaster
# Starblind - 2015 Remaster
# The Talisman - 2015 Remaster
# The Man Who Would Be King - 2015 Remaster
# When the Wild Wind Blows - 2015 Remaster

# %%
final_frontier.json()['tracks']['items'][6].keys()
# Out:
# dict_keys(['artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_urls', 'href', 'id', 'is_local', 'name', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# Observemos que hay un link a una preview de cada cación

# %%
final_frontier.json()['tracks']['items'][6]['preview_url']
# Out:
# 'https://p.scdn.co/mp3-preview/aaf1cdfd1e2a0390f4112ca4b21388c016d52207?cid=44b7b36ec145467f9a9eeaf7e417cf8b'

# %%
prev = requests.get(final_frontier.json()['tracks']['items'][6]['preview_url'])

# %%
prev.content
# Out:
# b'ID3\x04\x00\x00\x00\x00\x10\x00GEOB\x00\x00\x08{\x00\x00\x00application/json\x00metadata.json\x00None\x00{"loop_duration": 19.51988, "start_time": 131.1171769872845, "downbeats": [0.19502301271549527, 2.5840430127155116, 5.004803012715513, 7.415583012715501, 9.803063012715512, 12.2018430127155, 14.823003012715503, 17.364403012715513, 19.714903012715496, 22.078893012715497, 24.46280301271551, 26.877133012715518, 29.354733012715513], "beats": [0.19502301271549527, 0.9814330127155131, 1.7743930127155068, 2.5840430127155116, 3.4030730127155095, 4.2074530127155185, 5.004803012715513, 5.802383012715495, 6.608723012715501, 7.415583012715501, 8.212193012715517, 9.005393012715501, 9.803063012715512, 10.601033012715504, 11.401873012715498, 12.2018430127155, 13.076163012715512, 13.949883012715503, 14.823003012715503, 15.695523012715512, 16.5674430127155, 17.364403012715513, 18.15146301271551, 18.933333012715508, 19.714903012715496, 20.512113012715503, 21.303783012715513, 22.078893012715497, 2
# ...

# %%
import IPython.display as ipd

# %%
ipd.Audio(prev.content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Obteniendo varios álbumes a la vez
# Accediendo al endpoint *https://api.spotify.com/v1/albums*, podemos utilizar los parámetros de la request para obtener la información de varios álbumes a la vez. Primero debemos crear la lista de álbumes (de sus **id**):

# %%
ids = [album['id'] for album in albumes_im.json()['items']]
ids
# Out:
# ['3oFAX7PeOFbZnKiPmpUPv4',
#  '0h63qX1zO0DAJLacVY3I7x',
#  '4vSfHrq6XxVyMcJ6PguFR2',
#  '6QKC7ltfafdNeBZkzLdUvF',
#  '44myoe2TKVeLrIhfcN7xVK',
#  '3LymDdEISKszJqeN2z9DBI',
#  '2hkRvIhUnPXbUbDDim63eJ',
#  '1iPFLsjqez49QPCX9hPmIl',
#  '1qwuDINuttWBKVx64FiOIj',
#  '3CE0SB7URLI49lxJcykXUi',
#  '5owI29GbshVBbC72drceUA',
#  '5YAfxU5OZKqAvE1GZPRQYY',
#  '5nM0AuGFYzHeJSMxAkmLW9',
#  '3yTneaS0Z3xsAmCafaYjPw',
#  '1gdB9kn59KSAVG5VQcjdHi',
#  '6GfWgmPjUWdmjlR0qHWZj5',
#  '1kN3mPkY2Tg17XsbcVdiIb',
#  '2rVdAYBUuEnciOvQRrn4YL',
#  '5ZtuSlGBItIKJVuk70plPc',
#  '2Y8x0EEu7il0K2gCQIqVRh']

# %% [markdown]
# Preparemos la request

# %%
params = {'ids': ','.join(ids), 'market':'AR'}

# %%
url = url_base+'/v1/albums'

# %%
discografia = requests.get(url, headers=header, params=params)

# %%
discografia.status_code
# Out:
# 200

# %%
discografia.json()
# Out:
# {'albums': [{'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'copyrights': [{'text': '2017 Iron Maiden LLP under exclusive license to Parlophone Records Ltd, a Warner Music Group Company',
#      'type': 'C'},
#     {'text': '2017 Iron Maiden LLP under exclusive license to Parlophone Records Ltd, a Warner Music Group Company',
#      'type': 'P'}],
#    'external_ids': {'upc': '190295760861'},
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3oFAX7PeOFbZnKiPmpUPv4'},
#    'genres': [],
#    'href': 'https://api.spotify.com/v1/albums/3oFAX7PeOFbZnKiPmpUPv4',
#    'id': '3oFAX7PeOFbZnKiPmpUPv4',
#    'images': [{'height': 640,
# ...

# %%
discografia.json()['albums'][0].keys()
# Out:
# dict_keys(['album_type', 'artists', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'total_tracks', 'tracks', 'type', 'uri'])

# %%
discografia.json()['albums'][0]['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/albums/3oFAX7PeOFbZnKiPmpUPv4/tracks?offset=0&limit=50&market=AR',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'disc_number': 1,
#    'duration_ms': 466573,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6aMCbBm6rx5FOn2UgICfOd'},
#    'href': 'https://api.spotify.com/v1/tracks/6aMCbBm6rx5FOn2UgICfOd',
#    'id': '6aMCbBm6rx5FOn2UgICfOd',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'If Eternity Should Fail - Live at Qudos Bank Arena, Sydney, Australia, Friday, 5/6/2016',
# ...

# %% [markdown]
# Ya podemos acceder a los tracks de los álbumes solicitados mediante la lista que armamos consultando el artista. Pero Iron Maiden tiene más de 20 álbumes. Por qué sólo vemos 20? Procesemos la request nuevamente.

# %%
albumes_im = requests.get(url_base+ep, headers=header)
albumes_im.status_code
# Out:
# 200

# %%
albumes_im.json().keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
albumes_im.json()['limit']
# Out:
# 20

# %%
albumes_im.json()['next']
# Out:
# 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao/albums?offset=20&limit=20&include_groups=album,single,compilation,appears_on'

# %% [markdown]
# Por defecto la API de Spotify devuelve los primeros 20 elementos, pero vemos que usando los parámetros "limit" y "offset" podemos movernos dentro de la paginación de los resultados e ir haciendo requests sucesivas hasta obtener todos los discos.

# %% [markdown]
# Otra alternativa es averiguar el total de discos bajo la clave "total" y hacer una nueva request con limit = total y offset = 0

# %%
albumes_im.json()['total']
# Out:
# 77

# %%
params = {'limit': albumes_im.json()['total'],
          'offset': 0}
albumes_im_full = requests.get(url=url_base+ep, params=params, headers=header)

# %%
albumes_im_full.status_code
# Out:
# 400

# %% [markdown]
# La request no fue exitosa. Veamos por qué

# %%
albumes_im_full.json()
# Out:
# {'error': {'status': 400,
#   'message': 'Invalid limit, must be a number between 1 and 50'}}

# %% [markdown]
# Efectivamente, de la <a href="https://developer.spotify.com/documentation/web-api/reference/artists/get-artists-albums/">documentación</a> de Spotify indica que podemos pedir con un límite máximo de 50. Armemos una función para ir pidiendo los álbumes secuencialmente. Podemos usar la ruta en 'next' para pedir la siguiente página.

# %%
params = {'limit': 50, # Máximo permitido por Spotify
          'offset': 0}
albumes_im_full = requests.get(url=url_base+ep, params=params, headers=header)
albumes_im_full.status_code
# Out:
# 200

# %%
discografia_im = []

# %%
discografia_im += [item['id'] for item in albumes_im_full.json()['items']]

# %% [markdown]
# Ya tenemos los primeros 50 items y ahora podemos usar el valor de 'next' para obtener la próxima página.

# %%
albumes_im_full.json()['next']
# Out:
# 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao/albums?offset=50&limit=50&include_groups=album,single,compilation,appears_on'

# %%
albumes_im_full = requests.get(url=albumes_im_full.json()['next'], headers=header)
albumes_im_full.status_code
# Out:
# 200

# %% [markdown]
# Agregamos los nuevos albumes a la lista

# %%
discografia_im += [item['id'] for item in albumes_im_full.json()['items']]

# %% [markdown]
# Obtenemos la dirección de la próxima página

# %%
albumes_im_full.json()['next']

# %% [markdown]
# Vemos que está vacío el campo. Esto lo podemos usar para detectar que hemos llegado al final y no hay más álbumes para solicitar.

# %%
def obtener_discografia(artist_id, token, return_name=False, page_limit=50, country=None):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit, 
              'offset': 0,
              'country': country}
    lista = []
    r = requests.get(url, params=params, headers=header)
    
    if r.status_code != 200:
        print('Error en request.', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header) # El resto de los parámetros están dentro de la URL
        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    
    return lista

# %%
obtener_discografia(id_im, token, return_name=True)
# Out:
# [('3oFAX7PeOFbZnKiPmpUPv4', 'The Book of Souls: Live Chapter'),
#  ('0h63qX1zO0DAJLacVY3I7x', 'The Book of Souls: The Live Chapter'),
#  ('4vSfHrq6XxVyMcJ6PguFR2', 'The Book of Souls'),
#  ('6QKC7ltfafdNeBZkzLdUvF', 'The Book of Souls'),
#  ('44myoe2TKVeLrIhfcN7xVK', "Maiden England '88 (2013 Remaster)"),
#  ('3LymDdEISKszJqeN2z9DBI', 'En Vivo!'),
#  ('2hkRvIhUnPXbUbDDim63eJ', 'En Vivo! (Live at Estadio Nacional, Santiago)'),
#  ('1iPFLsjqez49QPCX9hPmIl', 'En Vivo! (Live at Estadio Nacional, Santiago)'),
#  ('1qwuDINuttWBKVx64FiOIj', 'The Final Frontier (2015 - Remaster)'),
#  ('3CE0SB7URLI49lxJcykXUi', 'The Final Frontier'),
#  ('5owI29GbshVBbC72drceUA', 'The Final Frontier (Deluxe Edition)'),
#  ('5YAfxU5OZKqAvE1GZPRQYY', 'The Final Frontier (2015 Remaster)'),
#  ('5nM0AuGFYzHeJSMxAkmLW9', 'Flight 666: The Original Soundtrack (Live)'),
#  ('3yTneaS0Z3xsAmCafaYjPw', 'Flight 666: The Original Soundtrack'),
#  ('1gdB9kn59KSAVG5VQcjdHi', 'A Matter of Life and Death (2015 Remaster)'),
# ...

# %% [markdown]
# Vemos que tenemos entradas duplicadas (mismo nombre, pero distinto ID). Esto se debe a que para cada país Spotify puede darle distintos IDs al mismo álbum.

# %%
obtener_discografia(id_im, token, return_name=True, country='AR')
# Out:
# [('3oFAX7PeOFbZnKiPmpUPv4', 'The Book of Souls: Live Chapter'),
#  ('4vSfHrq6XxVyMcJ6PguFR2', 'The Book of Souls'),
#  ('44myoe2TKVeLrIhfcN7xVK', "Maiden England '88 (2013 Remaster)"),
#  ('3LymDdEISKszJqeN2z9DBI', 'En Vivo!'),
#  ('5YAfxU5OZKqAvE1GZPRQYY', 'The Final Frontier (2015 Remaster)'),
#  ('3yTneaS0Z3xsAmCafaYjPw', 'Flight 666: The Original Soundtrack'),
#  ('1gdB9kn59KSAVG5VQcjdHi', 'A Matter of Life and Death (2015 Remaster)'),
#  ('2rVdAYBUuEnciOvQRrn4YL', 'Death on the Road'),
#  ('2Y8x0EEu7il0K2gCQIqVRh', 'Dance of Death (2015 Remaster)'),
#  ('4SiZSq9igWhpJoMzjxE1xE', 'Rock In Rio [Live]'),
#  ('1hDF0QPIHVTnSJtxyQVguB', 'Brave New World (2015 Remaster)'),
#  ('0axV6lvqshTCcGxT2AYiIK', 'Ed Hunter'),
#  ('4olc018Cln2QaMRFy1sk7v', 'Virtual XI (2015 Remaster)'),
#  ('3irqbaStVsDR9IEdg8Cdwz', 'The X Factor (2015 Remaster)'),
#  ('3DRvgymMVPG0TQ2DugHJRb', 'A Real Live Dead One (Live; 2006 Remaster)'),
#  ('12vTiEGN96ZQtGb3zfpKE8', 'A Real Live One'),
# ...

# %% [markdown]
# Ahora armemos una función que obtenga la lista de temas de cada álbum

# %%
def obtener_tracks(album_id, token, return_name=False, page_limit=50, country=None):
    url=f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit, 
              'offset': 0,
              'market': country}
    lista = []
    r = requests.get(url, params=params, headers=header)
    
    if r.status_code != 200:
        print('Error en request.', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header) # El resto de los parámetros están dentro de la URL
        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    
    return lista

# %% [markdown]
# Probemos con un album id cualquiera:

# %%
obtener_tracks('3DNeMApEMCo4IDXNMYnlFi', token, return_name=True, country='AR')
# Out:
# [('1198hsFUvkbffYd8Ff58DX', 'Prowler - 2015 Remaster'),
#  ('1NILMHSfpDZd7Rn73d7bEP', 'Remember Tomorrow - 2015 Remaster'),
#  ('5JX4CIPK47CU1iVeAWJtH5', 'Running Free - 2015 Remaster'),
#  ('14H2fE4WEdkEem0kjVeODT', 'Phantom of the Opera - 2015 Remaster'),
#  ('43QZUbTYnsU7ypUKxOyTRz', 'Transylvania - 2015 Remaster'),
#  ('2zg6aGS3qFpVYqEkGy0vVB', 'Strange World - 2015 Remaster'),
#  ('4C984NFYMwDm3idaxAPZb0', 'Charlotte the Harlot - 2015 Remaster'),
#  ('21wB3DaIk112Ry3mEzqfit', 'Iron Maiden - 2015 Remaster')]

# %% [markdown]
# Ahora podemos usar ambas funciones en combinación para obtener la lista de temas disponibles en Argentina de Iron Maiden, cada una con referencia a su album

# %%
for album in obtener_discografia(id_im, token, return_name=True, country='AR'):
    print(album[1])
    for track in obtener_tracks(album[0], token, return_name=True, country='AR'):
        print('\t',track[1])
# Out:
# The Book of Souls: Live Chapter
# 	 If Eternity Should Fail - Live at Qudos Bank Arena, Sydney, Australia, Friday, 5/6/2016
# 	 Speed of Light - Live at Grand Arena, GrandWest, Cape Town, South Africa, Wednesday, 5/18/2016
# 	 Wrathchild - Live at 3 Arena, Dublin, Ireland, Saturday, 5/6/2017
# 	 Children of the Damned - Live at Bell Center, Montreal, Canada, Friday, 4/1/2016
# 	 Death or Glory - Live at Wroclaw Stadium, Wroclaw, Poland, Sunday, 7/3/2016
# 	 The Red and the Black - Live at Ryogoku Kokugikan, Tokyo, Japan, Thursday, 4/21/2016
# 	 The Trooper - Live at Estadio Jorge Magico Gonzalez, San Salvador, El Salvador, Sunday, 3/6/2016
# 	 Powerslave - Live at Plaza Dell'Unita D'Italia, Trieste, Italy, Tuesday, 7/26/2016
# 	 The Great Unknown - Live at MRA Arena, Newcastle, England, Sunday, 5/14/2017
# 	 The Book of Souls - Live at Download Festival, Donington, England, Sunday, 6/12/2016
# 	 Fear of the Dark - Live at Arena Castelao, Fortaleza, Brazil, Thursday, 3/24/2016
# ...
