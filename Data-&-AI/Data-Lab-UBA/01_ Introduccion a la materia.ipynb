# %% [markdown]
# Este es un notebook de ejemplo para familiarizarse con el formato y aprender a leer archivos desde Google Drive.
#
# Este es un box de texto. Lo usamos para narrar y explicar lo que hace el código. Es similar a un editor de texto, con efectos como **negritas**, *itálicas*, [link a las clases](https://materias.df.uba.ar/lda2021c1/),
#
# ```
# cajas con formato de código (no ejecutable)
# ```
# e imágenes:
#
# ![thumb-jupiter-5c39bbb17d9918b1ae9862ae42ef59dc.png](data:image/png;base64,...)
#
# Además, podemos usar expresiones de LaTeX para escribir matemática: $4^4$, $\sum_i a_i$, etc.
#
# Las cajas de texto estan intercaladas con cajas de código que se ejecutan secuencialmente y muestran los resultados. El código se ejecuta en infraestructura de Google (la "nube") por lo que no tenemos que instalar nada en nuestra computadora.

# %%
a = ["hola", "mundo"]
print(a[0] + ' ' + a[1])
# Out:
# hola mundo

# %% [markdown]
# En la materia vamos a tener que cargar datasets para realizar distintos análisis. Para eso, el primer paso es tener acceso al directorio de Google Drive donde vamos a poner los distintos datasets. Podemos acceder usando el siguiente link: https://drive.google.com/drive/folders/1H2M_oPYoMKUGrWZazlySBmtWaKiLbjTV?usp=sharing
#
# Una vez que tenemos acceso, tenemos que agregar acceso directo a Drive.
#
# Finalmente, tenemos montar el directorio de drive en Google Colab ejecutando el siguiente código y siguiendo las instrucciones.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Luego, podemos cargar un archivo específico ("ejemplo_clase_1.txt") indicando antes el path correspondiente.

# %%
filename = '/content/drive/My Drive/LaboDatos2021/ejemplo_clase_1.txt' 
f = open(filename, "r")
print(f.read())
